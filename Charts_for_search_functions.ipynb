# %% [markdown]
# <a href="https://colab.research.google.com/github/IgoninID/ArraysSAOD/blob/master/Charts_for_search_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt2

x  = [100000000, 200000000, 300000000, 400000000, 500000000]
y1 = [38.14, 69.75, 113.34, 143.46, 176.42]
plt.plot(x, y1, label="Search func")

plt.xlabel("size mil")
plt.ylabel("average time milsec")
plt.title("BigO Search (n)")
plt.grid(1)
plt.legend()
plt.show()

x2 = [2000000000, 2050000000, 2100000000, 2150000000, 2200000000, 2250000000, 2300000000, 2350000000, 2400000000, 2450000000, 2500000000]
y2 = [546, 629, 669, 685, 674, 704, 759, 784, 775, 803, 834]
plt2.plot(x2, y2, label="Binary search")

plt2.xlabel("size bil")
plt2.ylabel("time milsec for 500000 iterations")
plt2.title("BigO Binary search (log n)")
plt2.grid(1)
plt2.legend()
plt2.show()
